# %%
import random

import matplotlib as mpl
import numpy as np
import torch
import torch.utils.data

import theseus as th
import theseus.utils.examples as theg

# %load_ext autoreload
# %autoreload 2

torch.set_default_dtype(torch.double)

device = "cuda:0" if torch.cuda.is_available else "cpu"
seed = 0
torch.random.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

mpl.rcParams["figure.facecolor"] = "white"
mpl.rcParams["font.size"] = 16

# %%
dataset_dir = "/home/peteryu/SEANRobotGuide/data/motion-planning-2d/dataset"
train_dataset = theg.TrajectoryDataset(True, 1000, dataset_dir, map_type="tarpit", filter_collision_maps=False)
train_dl = torch.utils.data.DataLoader(train_dataset, batch_size=32)

# test_dataset = theg.TrajectoryDataset(False, 1000, dataset_dir, val_ratio=0.3, map_type="tarpit", )
# test_dl = torch.utils.data.DataLoader(test_dataset)

print(len(train_dl))

batch = next(iter(train_dl))
for k, v in batch.items():
    if k != "file_id":
        print(f"{k:20s}: {v.shape}")
    else:
        print(f"{k:20s}: {v}")
# Out:
# 32
# map_tensor          : torch.Size([32, 128, 128])
# sdf_origin          : torch.Size([32, 2])
# cell_size           : torch.Size([32, 1])
# sdf_data            : torch.Size([32, 128, 128])
# expert_trajectory   : torch.Size([32, 4, 101])
# file_id             : ['tarpit_877', 'tarpit_360', 'tarpit_539', 'tarpit_434', 'tarpit_236', 'tarpit_306', 'tarpit_678', 'tarpit_72', 'tarpit_32', 'tarpit_379', 'tarpit_580', 'tarpit_227', 'tarpit_513', 'tarpit_810', 'tarpit_138', 'tarpit_642', 'tarpit_295', 'tarpit_423', 'tarpit_588', 'tarpit_764', 'tarpit_331', 'tarpit_18', 'tarpit_261', 'tarpit_78', 'tarpit_820', 'tarpit_611', 'tarpit_120', 'tarpit_265', 'tarpit_711', 'tarpit_337', 'tarpit_73', 'tarpit_782']

# %%
trajectory_len = 101
num_time_steps = trajectory_len - 1
map_size = 128
safety_distance = 0.4
robot_radius = 0.4
total_time = 10.0
dt_val = total_time / num_time_steps
Qc_inv = [[1.0, 0.0], [0.0, 1.0]]
collision_w = 20.0
boundary_w = 100.0

# %%
# Create optimization variables
poses = []
velocities = []
for i in range(trajectory_len):
    poses.append(th.Point2(name=f"pose_{i}", dtype=torch.double))
    velocities.append(th.Point2(name=f"vel_{i}", dtype=torch.double))

# %%
# Targets for pose boundary cost functions
start_point = th.Point2(name="start")
goal_point = th.Point2(name="goal")

# For collision avoidance cost function
sdf_origin = th.Point2(name="sdf_origin")
cell_size = th.Variable(torch.empty(1, 1), name="cell_size")
sdf_data = th.Variable(torch.empty(1, map_size, map_size), name="sdf_data")
cost_eps = th.Variable(torch.tensor(robot_radius + safety_distance).view(1, 1), name="cost_eps")

# For GP dynamics cost function
dt = th.Variable(torch.tensor(dt_val).view(1, 1), name="dt")

# %%
# Cost weight to use for all GP-dynamics cost functions
gp_cost_weight = th.eb.GPCostWeight(torch.tensor(Qc_inv), dt)

# Cost weight to use for all collision-avoidance cost functions
collision_cost_weight = th.ScaleCostWeight(th.Variable(torch.tensor(collision_w)))

# For all hard-constraints (end points pos/vel) we use a single scalar weight
# with high value
boundary_cost_weight = th.ScaleCostWeight(boundary_w)

# %%
objective = th.Objective(dtype=torch.double)
# Fixed starting position
objective.add(
    th.Difference(poses[0], start_point, boundary_cost_weight, name="pose_0")
)
# Fixed initial velocity
objective.add(
    th.Difference(
        velocities[0],
        th.Point2(tensor=torch.zeros(1, 2)),
        boundary_cost_weight,
        name="vel_0",
    )
)
objective.add(
    th.Difference(
        poses[-1], goal_point, boundary_cost_weight, name="pose_N"
    )
)
objective.add(
    th.Difference(
        velocities[-1],
        th.Point2(tensor=torch.zeros(1, 2)),
        boundary_cost_weight,
        name="vel_N",
    )
)

# %%
for i in range(1, trajectory_len - 1):
    objective.add(
        th.eb.Collision2D(
            poses[i],
            sdf_origin,
            sdf_data,
            cell_size,
            cost_eps,
            collision_cost_weight,
            name=f"collision_{i}",
        )
    )

# %%
for i in range(1, trajectory_len):
    objective.add(
        (
            th.eb.GPMotionModel(
                poses[i - 1],
                velocities[i - 1],
                poses[i],
                velocities[i],
                dt,
                gp_cost_weight,
                name=f"gp_{i}",
            )
        )
    )

# %%
optimizer = th.LevenbergMarquardt(
    objective,
    th.CholeskyDenseSolver,
    max_iterations=50,
    step_size=1.0,
)
motion_planner = th.TheseusLayer(optimizer)
motion_planner.to(device=device, dtype=torch.double)

# %%
def get_straight_line_inputs(start, goal):
    # Returns a dictionary with pose and velocity variable names associated to a 
    # straight line trajectory between start and goal
    start_goal_dist = goal - start
    avg_vel = start_goal_dist / total_time
    unit_trajectory_len = start_goal_dist / (trajectory_len - 1)
    input_dict = {}
    for i in range(trajectory_len):
        input_dict[f"pose_{i}"] = start + unit_trajectory_len * i
        if i == 0 or i == trajectory_len - 1:
            input_dict[f"vel_{i}"] = torch.zeros_like(avg_vel)
        else:
            input_dict[f"vel_{i}"] = avg_vel
    return input_dict

# %%
start = batch["expert_trajectory"][:, :2, 0].to(device)
goal = batch["expert_trajectory"][:, :2, -1].to(device)
planner_inputs = {
    "sdf_origin": batch["sdf_origin"].to(device),
    "start": start.to(device),
    "goal": goal.to(device),
    "cell_size": batch["cell_size"].to(device),
    "sdf_data": batch["sdf_data"].to(device),
}
planner_inputs.update(get_straight_line_inputs(start, goal))    
with torch.no_grad():        
    final_values, info = motion_planner.forward(
        planner_inputs,
        optimizer_kwargs={
            "track_best_solution": True,
            "verbose": True,
            "damping": 0.1,
        }
    )
# Out:
# Nonlinear optimizer. Iteration: 0. Error: 4397.2986487033995
# Nonlinear optimizer. Iteration: 1. Error: 1727.8121663401948
# Nonlinear optimizer. Iteration: 2. Error: 1308.5222945990688
# Nonlinear optimizer. Iteration: 3. Error: 973.6160758438334
# Nonlinear optimizer. Iteration: 4. Error: 1269.2885492324895
# Nonlinear optimizer. Iteration: 5. Error: 1286.520021929311
# Nonlinear optimizer. Iteration: 6. Error: 1372.32025679641
# Nonlinear optimizer. Iteration: 7. Error: 1290.247075621777
# Nonlinear optimizer. Iteration: 8. Error: 1582.0649241964095
# Nonlinear optimizer. Iteration: 9. Error: 1729.7149191760232
# Nonlinear optimizer. Iteration: 10. Error: 1793.7260399223712
# Nonlinear optimizer. Iteration: 11. Error: 2038.7021848729676
# Nonlinear optimizer. Iteration: 12. Error: 1910.8296754554062
# Nonlinear optimizer. Iteration: 13. Error: 1753.759609172211
# Nonlinear optimizer. Iteration: 14. Error: 1744.1563313680153
# Nonlinear optimizer. Iteration: 15. Error: 1883.1292015438526
# Nonlinear optimizer. Iteration: 16. Error: 1941.1743733407234
# Nonlinear optimizer. Iteration: 17. Error: 1937.9829760266227
# Nonlinear optimizer. Iteration: 18. Error: 1893.7874642010609
# Nonlinear optimizer. Iteration: 19. Error: 2090.4926243663817
# Nonlinear optimizer. Iteration: 20. Error: 2032.055137597272
# Nonlinear optimizer. Iteration: 21. Error: 2045.8230582054177
# Nonlinear optimizer. Iteration: 22. Error: 1970.5489126371758
# Nonlinear optimizer. Iteration: 23. Error: 2130.5423461107234
# Nonlinear optimizer. Iteration: 24. Error: 2077.755913969465
# Nonlinear optimizer. Iteration: 25. Error: 2097.3429374351736
# Nonlinear optimizer. Iteration: 26. Error: 2101.7658739421413
# Nonlinear optimizer. Iteration: 27. Error: 2107.3812280056795
# Nonlinear optimizer. Iteration: 28. Error: 1889.8372974801364
# Nonlinear optimizer. Iteration: 29. Error: 1875.4995407103502
# Nonlinear optimizer. Iteration: 30. Error: 1839.7630984030545
# Nonlinear optimizer. Iteration: 31. Error: 1831.158166234115
# Nonlinear optimizer. Iteration: 32. Error: 1853.1404834227656
# Nonlinear optimizer. Iteration: 33. Error: 1931.5171117715997
# Nonlinear optimizer. Iteration: 34. Error: 2037.4104829715081
# Nonlinear optimizer. Iteration: 35. Error: 2013.4984053158373
# Nonlinear optimizer. Iteration: 36. Error: 1880.3227059618705
# Nonlinear optimizer. Iteration: 37. Error: 1831.2805432489038
# Nonlinear optimizer. Iteration: 38. Error: 1738.6453152104723
# Nonlinear optimizer. Iteration: 39. Error: 1625.2813328263535
# Nonlinear optimizer. Iteration: 40. Error: 1596.05775598914
# Nonlinear optimizer. Iteration: 41. Error: 1650.260248709081
# Nonlinear optimizer. Iteration: 42. Error: 1665.7861800838018
# Nonlinear optimizer. Iteration: 43. Error: 1533.0864075259988
# Nonlinear optimizer. Iteration: 44. Error: 1699.958351587757
# Nonlinear optimizer. Iteration: 45. Error: 1525.625695576887
# Nonlinear optimizer. Iteration: 46. Error: 1408.9027452759387
# Nonlinear optimizer. Iteration: 47. Error: 1389.5813544369817
# Nonlinear optimizer. Iteration: 48. Error: 1302.5919380758025
# Nonlinear optimizer. Iteration: 49. Error: 1124.0992667503979
# Nonlinear optimizer. Iteration: 50. Error: 1097.4371866165861

# %%
def get_trajectory(values_dict):
    trajectory = torch.empty(values_dict[f"pose_0"].shape[0], 4, trajectory_len, device=device)
    for i in range(trajectory_len):
        trajectory[:, :2, i] = values_dict[f"pose_{i}"]
        trajectory[:, 2:, i] = values_dict[f"vel_{i}"]
    return trajectory

# %%
trajectories = get_trajectory(info.best_solution).cpu()
print(trajectories.size())
# Out:
# torch.Size([32, 4, 101])

# %%
for i in range(5):
    sdf = th.eb.SignedDistanceField2D(
        th.Point2(batch["sdf_origin"][i].unsqueeze(0)),
        th.Variable(batch["cell_size"][i].unsqueeze(0)),
        th.Variable(batch["sdf_data"][i].unsqueeze(0)),
    )
    figs = theg.generate_trajectory_figs(
        batch["map_tensor"][i].unsqueeze(0), 
        sdf, 
        [trajectories[i].unsqueeze(0)], 
        robot_radius=robot_radius, 
        labels=["solution trajectory"], 
        fig_idx_robot=0,
        figsize=(6, 6)
    )
    figs[0].show()
# Out:
# /tmp/ipykernel_1393423/3433490607.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figs[0].show()
